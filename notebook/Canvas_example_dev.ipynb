# %% [markdown]
# # Test for processing Canvas data: Dev
#
# This notebook demonstrates possible data processing and exploration of the Canvas data, using the OEA_py class notebook.
#
# Most of the data processing done in this notebook are also achieved by executing the Canvas module main pipeline. This notebook is designed as an alternate approach to the same processing, as well as module data exploration and visualization.
#
# The steps are clearly outlined below:
# 1. Set the workspace,
# 2. Land Canvas Module Higher Ed. Test Data,
# 3. Pre-Process Canvas Module Test Data,
# 4. Ingest the Canvas Module Test Data,
# 5. Refine the Canvas Module Test Data,
# 6. Demonstrate Lake Database Queries/Final Remarks, and
# 7. Appendix

# %%
# %run OEA_py
# Out:
# StatementMeta(, 2, -1, Finished, Available)
# 2023-05-19 16:14:30,335 - OEA - INFO - Now using workspace: dev
# 2023-05-19 16:14:30,336 - OEA - INFO - OEA initialized.

# %%
# 1) set the workspace (this determines where in the data lake you'll be writing to and reading from).
# You can work in 'dev', 'prod', or a sandbox with any name you choose.
# For example, Sam the developer can create a 'sam' workspace and expect to find his datasets in the data lake under oea/sandboxes/sam
oea.set_workspace('dev')
# Out:
# StatementMeta(spark3p3sm, 2, 3, Finished, Available)
# 2023-05-19 16:14:32,424 - OEA - INFO - Now using workspace: dev

# %% [markdown]
# ## 2.) Land Canvas Module Higher Ed. Test Data
#
# Directory: ```GitHub.com (raw data) -> stage1/Transactional/canvas```
#
# The code block below lands 10 OEA Canvas module test data tables, formatted as Canvas Higher Ed. data in your data lake.
#
# Canvas test data tables landed in stage 1:
#  1. **accounts**
#  2. **assignments**
#  3. **assignment_submissions**
#  4. **assignment_submission_summary**
#  5. **courses**
#  6. **course_sections**
#  7. **enrollments**
#  8. **enrollment_terms**
#  9. **roles**
#  10. **users**
#
# **To-Do's:**
#  - Correct the test dataset as needed
#  - Remove top codeblock for when launching on OEA.

# %%
# In this example we pull Canvas HEd test json data files from github and land it in oea/dev/stage1/Transactional/canvas/v2.0
import datetime
currentDate = datetime.datetime.now()
currentDateTime = currentDate.strftime("%Y-%m-%d %H-%M-%S")
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/accounts.json').text
oea.land(data, 'canvas/v2.0/accounts', 'accounts_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/courses.json').text
oea.land(data, 'canvas/v2.0/courses', 'courses_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/roles.json').text
oea.land(data, 'canvas/v2.0/roles', 'roles_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/course_sections.json').text
oea.land(data, 'canvas/v2.0/course_sections', 'coursesections_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/users.json').text
oea.land(data, 'canvas/v2.0/users', 'users_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
# normally, these three tables should be landed as delta_batch_data but since functionality is limited for processing delta data, we assume they're snapshot for now.
#data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/assignment_submission_summary.json').text
#oea.land(data, 'canvas/v2.0/assignment_sumbission_summary', 'assignsubsummary_hed_test_data.csv', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/enrollments.json').text
oea.land(data, 'canvas/v2.0/enrollments', 'enrollments_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)
data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/enrollment_terms.json').text
oea.land(data, 'canvas/v2.0/enrollment_terms', 'enrollmentterms_hed_test_data.json', oea.SNAPSHOT_BATCH_DATA, currentDateTime)

#data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/assignment_submissions.json').text
#oea.land(data, 'canvas/v2.0/assignment_submissions', 'assignsubmissions_hed_test_data.csv', oea.ADDITIVE_BATCH_DATA, currentDateTime)
#data = requests.get('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/hed_test_data/assignments.json').text
#oea.land(data, 'canvas/v2.0/assignments', 'assignments_hed_test_data.csv', oea.ADDITIVE_BATCH_DATA, currentDateTime)
# Out:
# StatementMeta(spark3p3sm, 2, 51, Finished, Available)
# 'stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate=2023-05-19 18-19-11/enrollmentterms_hed_test_data.json'

# %% [markdown]
# ## 3.) Pre-Process Canvas Module Test Data
#
# Directory: ```stage1/Transactional/canvas -> stage1/Transactional/canvas```
#
# This step is responsible for pre-processing the Canvas module test data from stage1 back to stage1.
#
# The code blocks in this step read in the original JSON tables using the ```pd.read_json(..., lines=True)``` function, performs any ad hoc data conversions, and writes the table to stage1 as a CSV.
#
# **To-Do's:**
#  - Check if this is to be adopted as a standard for JSONs oriented as records (one JSON row represents a row in the df).

# %%
# x) this step pre-processing the canvas data through reading in the JSONs as records, corrects any schema discepancies and then writes out the df as a CSV in stage1.
import datetime
currentDate = datetime.datetime.now()
currentDateTime = currentDate.strftime("%Y-%m-%d %H-%M-%S")

def clean_data_lake_latest(source_path):
    """only house the latest rundate folder compared to the old data (which were JSONs)"""
    latest_folder = oea.get_latest_folder(source_path)
    items = mssparkutils.fs.ls(oea.to_url(source_path))
    for item in items:
        if item.name != latest_folder:
            logger.info('file removal path: ' + item.path + ' with item: ' + item.name)
            oea.rm_if_exists(source_path + '/' + item.name)
            logger.info('Successfully removed folder: ' + item.name + ' from path: ' + item.path)
        else:
            logger.info('Kept folder: ' + item.name + ' from path: ' + item.path)
    logger.info('Finished cleaning data lake to house only the latest folder')

def write_canvas_json_as_csv(write_filepath,batch_type,df):
    df.coalesce(1).write.save(oea.to_url(f'{write_filepath}/{batch_type}_batch_data/rundate={currentDateTime}'), format='csv', mode='overwrite', header='true', mergeSchema='true')

def preprocess_canvas_dataset(tables_source):
    items = oea.get_folders(tables_source)
    for item in items: 
        table_path = tables_source +'/'+ item
        #batch_type = oea.get_folders(table_path)
        pdf = pd.read_json(oea.to_url(f'{table_path}/snapshot_batch_data/*/*.json'),lines=True)
        df = spark.createDataFrame(pdf)
        if item == 'accounts':
            df = df.withColumn('parent_account_id', df['parent_account_id'].cast(LongType()))
            write_canvas_json_as_csv(table_path,'snapshot',df)
            #clean_data_lake_latest(f'{table_path}/snapshot_batch_data')
        else:
            write_canvas_json_as_csv(table_path,'snapshot',df)
        clean_data_lake_latest(f'{table_path}/snapshot_batch_data')
        new_table_path = f'{table_path}/snapshot_batch_data/rundate={currentDateTime}'
        oea.rm_if_exists(new_table_path + '/_SUCCESS', False)
        #if batch_type == 'snapshot_batch_data':
        #    pdf = pd.read_json(oea.to_url(f'{table_path}/snapshot_batch_data/*/*.json'),lines=True)
        #    df = spark.createDataFrame(pdf)
        #    if item == 'accounts':
        #        df = df.withColumn('parent_account_id', df['parent_account_id'].cast(LongType()))
        #        write_canvas_json_as_csv(table_path,'snapshot',df)
                #clean_data_lake_latest(f'{table_path}/snapshot_batch_data')
        #    else:
        #        write_canvas_json_as_csv(table_path,'snapshot',df)
                #clean_data_lake_latest(f'{table_path}/snapshot_batch_data')
            # now write to CSV and clean stage1 of the lake
            #write_canvas_json_as_csv(table_path,'snapshot',df)
            #clean_data_lake_latest(f'{table_path}/snapshot_batch_data')
        #elif batch_type == 'delta_batch_data':
        #    pdf = pd.read_json(oea.to_url(f'{table_path}/delta_batch_data/*/*.json'),lines=True)
        #    df = spark.createDataFrame(pdf)
        #    write_canvas_json_as_csv(table_path,'delta',df)
        #    clean_data_lake_latest(f'{table_path}/delta_batch_data')
        #elif batch_type == 'additive_batch_data':
        #    pdf = pd.read_json(oea.to_url(f'{table_path}/additive_batch_data/*/*.json'),lines=True)
        #    df = spark.createDataFrame(pdf)
        #    write_canvas_json_as_csv(table_path,'additive',df)
        #    clean_data_lake_latest(f'{table_path}/additive_batch_data')
        logger.info('Pre-processed table: ' + item + ' from: ' + table_path)
    logger.info('Finished pre-processing Canvas tables')
# Out:
# StatementMeta(spark3p3sm, 2, 52, Finished, Available)

# %%
# set the version number and pre-process the dataset
version = '2.0'
preprocess_canvas_dataset(f'stage1/Transactional/canvas/v{version}')
# Out:
# StatementMeta(spark3p3sm, 2, 53, Finished, Available)
# 2023-05-19 18:19:28,439 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b1484280-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,480 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b335fa-a01e-0028-687e-8ac95f000000'
#     'x-ms-client-request-id': 'b1484280-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,481 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b14e9b6c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,495 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3360f-a01e-0028-797e-8ac95f000000'
#     'x-ms-client-request-id': 'b14e9b6c-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,496 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b150f95c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,508 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33618-a01e-0028-027e-8ac95f000000'
#     'x-ms-client-request-id': 'b150f95c-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,509 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b152ede8-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,521 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33629-a01e-0028-117e-8ac95f000000'
#     'x-ms-client-request-id': 'b152ede8-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,523 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b155016e-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,534 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33635-a01e-0028-1d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b155016e-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,535 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b156d61a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,548 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3363f-a01e-0028-267e-8ac95f000000'
#     'x-ms-client-request-id': 'b156d61a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,551 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/accounts_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b159627c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,561 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '38566'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:11 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958B8F1088"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33650-a01e-0028-357e-8ac95f000000'
#     'x-ms-client-request-id': 'b159627c-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:28,563 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/accounts_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b15b2698-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:28,586 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '38566'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:11 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958B8F1088"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33659-a01e-0028-3e7e-8ac95f000000'
#     'x-ms-client-request-id': 'b15b2698-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:27 GMT'
# 2023-05-19 18:19:29,954 - OEA - INFO - file removal path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate=2023-05-19 18-19-11 with item: rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:29,996 - OEA - INFO - Successfully removed folder: rundate=2023-05-19 18-19-11 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:29,996 - OEA - INFO - Kept folder: rundate=2023-05-19 18-19-17 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:19:29,996 - OEA - INFO - Finished cleaning data lake to house only the latest folder
# 2023-05-19 18:19:30,025 - OEA - INFO - Pre-processed table: accounts from: stage1/Transactional/canvas/v2.0/accounts
# 2023-05-19 18:19:30,027 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b23a98f0-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,040 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b08-a01e-0028-077e-8ac95f000000'
#     'x-ms-client-request-id': 'b23a98f0-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,041 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b23ca4ec-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,057 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b12-a01e-0028-117e-8ac95f000000'
#     'x-ms-client-request-id': 'b23ca4ec-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,059 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b23f5fac-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,071 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b1f-a01e-0028-1e7e-8ac95f000000'
#     'x-ms-client-request-id': 'b23f5fac-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,072 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b24178d2-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,089 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b31-a01e-0028-307e-8ac95f000000'
#     'x-ms-client-request-id': 'b24178d2-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,091 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b2444a80-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,102 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b3e-a01e-0028-3d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b2444a80-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,103 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b246283c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,117 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b44-a01e-0028-437e-8ac95f000000'
#     'x-ms-client-request-id': 'b246283c-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,121 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/coursesections_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b248ec2a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,132 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '34909'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C3FF4A9"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b54-a01e-0028-517e-8ac95f000000'
#     'x-ms-client-request-id': 'b248ec2a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:30,133 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/coursesections_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b24acc7a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:30,150 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '34909'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C3FF4A9"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33b63-a01e-0028-5e7e-8ac95f000000'
#     'x-ms-client-request-id': 'b24acc7a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:29 GMT'
# 2023-05-19 18:19:31,224 - OEA - INFO - file removal path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate=2023-05-19 18-19-11 with item: rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:31,265 - OEA - INFO - Successfully removed folder: rundate=2023-05-19 18-19-11 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:31,266 - OEA - INFO - Kept folder: rundate=2023-05-19 18-19-17 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:19:31,266 - OEA - INFO - Finished cleaning data lake to house only the latest folder
# 2023-05-19 18:19:31,286 - OEA - INFO - Pre-processed table: course_sections from: stage1/Transactional/canvas/v2.0/course_sections
# 2023-05-19 18:19:31,288 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b2faf226-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,303 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33f7e-a01e-0028-0c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b2faf226-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,304 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b2fd796a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,316 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33f9c-a01e-0028-287e-8ac95f000000'
#     'x-ms-client-request-id': 'b2fd796a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,317 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b2ff7a3a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,329 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fab-a01e-0028-377e-8ac95f000000'
#     'x-ms-client-request-id': 'b2ff7a3a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,330 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3016c1e-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,342 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fbc-a01e-0028-467e-8ac95f000000'
#     'x-ms-client-request-id': 'b3016c1e-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,344 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b303949e-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,359 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fd2-a01e-0028-5c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b303949e-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,360 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b305f0e0-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,373 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fd9-a01e-0028-637e-8ac95f000000'
#     'x-ms-client-request-id': 'b305f0e0-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,377 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/courses_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3089020-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,386 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '37286'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958BCCEB97"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fe7-a01e-0028-707e-8ac95f000000'
#     'x-ms-client-request-id': 'b3089020-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:31,387 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/courses_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b30a2200-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:31,399 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '37286'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958BCCEB97"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b33fee-a01e-0028-777e-8ac95f000000'
#     'x-ms-client-request-id': 'b30a2200-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:30 GMT'
# 2023-05-19 18:19:32,255 - OEA - INFO - file removal path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate=2023-05-19 18-19-11 with item: rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:32,293 - OEA - INFO - Successfully removed folder: rundate=2023-05-19 18-19-11 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:32,294 - OEA - INFO - Kept folder: rundate=2023-05-19 18-19-17 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:19:32,294 - OEA - INFO - Finished cleaning data lake to house only the latest folder
# 2023-05-19 18:19:32,315 - OEA - INFO - Pre-processed table: courses from: stage1/Transactional/canvas/v2.0/courses
# 2023-05-19 18:19:32,317 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b39800c0-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,331 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b342dc-a01e-0028-207e-8ac95f000000'
#     'x-ms-client-request-id': 'b39800c0-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,332 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b39a547e-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,346 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b342eb-a01e-0028-2d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b39a547e-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,347 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b39c92b6-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,359 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b342fe-a01e-0028-3e7e-8ac95f000000'
#     'x-ms-client-request-id': 'b39c92b6-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,360 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b39e82c4-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,374 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3430b-a01e-0028-4a7e-8ac95f000000'
#     'x-ms-client-request-id': 'b39e82c4-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,376 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3a10b8e-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,387 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34314-a01e-0028-537e-8ac95f000000'
#     'x-ms-client-request-id': 'b3a10b8e-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,388 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3a2cb4a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,399 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3431f-a01e-0028-5c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b3a2cb4a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,403 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/enrollmentterms_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3a50f72-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,417 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '309'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:13 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958CC81662"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34332-a01e-0028-6d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b3a50f72-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:32,418 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/enrollmentterms_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b3a76b46-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:32,437 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '309'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:13 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958CC81662"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3433b-a01e-0028-757e-8ac95f000000'
#     'x-ms-client-request-id': 'b3a76b46-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:31 GMT'
# 2023-05-19 18:19:33,315 - OEA - INFO - file removal path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate=2023-05-19 18-19-11 with item: rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:33,416 - OEA - INFO - Successfully removed folder: rundate=2023-05-19 18-19-11 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:33,417 - OEA - INFO - Kept folder: rundate=2023-05-19 18-19-17 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:19:33,417 - OEA - INFO - Finished cleaning data lake to house only the latest folder
# 2023-05-19 18:19:33,439 - OEA - INFO - Pre-processed table: enrollment_terms from: stage1/Transactional/canvas/v2.0/enrollment_terms
# 2023-05-19 18:19:33,442 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b443a092-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:33,453 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3474b-a01e-0028-2c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b443a092-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:32 GMT'
# 2023-05-19 18:19:33,454 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b44576e2-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:33,466 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34758-a01e-0028-397e-8ac95f000000'
#     'x-ms-client-request-id': 'b44576e2-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:32 GMT'
# 2023-05-19 18:19:33,468 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b4478efa-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:33,481 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3476c-a01e-0028-4c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b4478efa-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:32 GMT'
# 2023-05-19 18:19:33,482 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b449b6e4-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:33,493 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3477b-a01e-0028-5b7e-8ac95f000000'
#     'x-ms-client-request-id': 'b449b6e4-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:32 GMT'
# 2023-05-19 18:19:33,495 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b44bc04c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:33,507 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
# ...
#     'x-ms-client-request-id': 'b4fd1b30-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:34,669 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34c81-a01e-0028-7c7e-8ac95f000000'
#     'x-ms-client-request-id': 'b4fd1b30-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:34 GMT'
# 2023-05-19 18:19:34,672 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/roles_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b4ff524c-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:34,683 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '454'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C0E6F0E"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34c93-a01e-0028-0d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b4ff524c-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:34 GMT'
# 2023-05-19 18:19:34,685 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/roles_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b50147a0-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:34,697 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '454'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:12 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C0E6F0E"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b34c9b-a01e-0028-157e-8ac95f000000'
#     'x-ms-client-request-id': 'b50147a0-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:34 GMT'
# 2023-05-19 18:19:35,585 - OEA - INFO - file removal path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate=2023-05-19 18-19-11 with item: rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:35,648 - OEA - INFO - Successfully removed folder: rundate=2023-05-19 18-19-11 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate=2023-05-19 18-19-11
# 2023-05-19 18:19:35,648 - OEA - INFO - Kept folder: rundate=2023-05-19 18-19-17 from path: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:19:35,648 - OEA - INFO - Finished cleaning data lake to house only the latest folder
# 2023-05-19 18:19:35,673 - OEA - INFO - Pre-processed table: roles from: stage1/Transactional/canvas/v2.0/roles
# 2023-05-19 18:19:35,676 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b59875a8-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,689 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35021-a01e-0028-537e-8ac95f000000'
#     'x-ms-client-request-id': 'b59875a8-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,690 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b59a9ba8-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,701 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3502c-a01e-0028-5e7e-8ac95f000000'
#     'x-ms-client-request-id': 'b59a9ba8-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,702 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b59c86a2-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,714 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35034-a01e-0028-667e-8ac95f000000'
#     'x-ms-client-request-id': 'b59c86a2-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,714 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b59e6562-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,739 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b3503b-a01e-0028-6d7e-8ac95f000000'
#     'x-ms-client-request-id': 'b59e6562-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,741 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b5a277a6-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,751 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35050-a01e-0028-027e-8ac95f000000'
#     'x-ms-client-request-id': 'b5a277a6-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,752 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea?restype=REDACTED&comp=REDACTED&prefix=REDACTED&delimiter=REDACTED&include=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b5a41e80-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,762 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35056-a01e-0028-087e-8ac95f000000'
#     'x-ms-client-request-id': 'b5a41e80-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,765 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/users/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/users_hed_test_data.json'
# Request method: 'HEAD'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b5a62c2a-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,787 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 200
# Response headers:
#     'Content-Length': '204694'
#     'Content-Type': 'application/octet-stream'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:13 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C6BDA32"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35066-a01e-0028-187e-8ac95f000000'
#     'x-ms-client-request-id': 'b5a62c2a-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-access-tier': 'REDACTED'
#     'x-ms-access-tier-inferred': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# 2023-05-19 18:19:35,789 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'https://stoeacisd3v08oct.blob.core.windows.net/oea/dev/stage1/Transactional/canvas/v2.0/users/snapshot_batch_data/rundate%3D2023-05-19%2018-19-11/users_hed_test_data.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b5a9c952-f671-11ed-bb1c-000d3a17ca77'
#     'User-Agent': 'azsdk-python-storage-blob/12.14.1 Python/3.10.6 (Linux-4.15.0-1164-azure-x86_64-with-glibc2.27)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2023-05-19 18:19:35,804 - azure.core.pipeline.policies.http_logging_policy - INFO - Response status: 206
# Response headers:
#     'Content-Length': '204694'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Fri, 19 May 2023 18:19:13 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'Etag': '"0x8DB58958C6BDA32"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '00b35076-a01e-0028-267e-8ac95f000000'
#     'x-ms-client-request-id': 'b5a9c952-f671-11ed-bb1c-000d3a17ca77'
#     'x-ms-version': 'REDACTED'
#     'x-ms-resource-type': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'x-ms-owner': 'REDACTED'
#     'x-ms-group': 'REDACTED'
#     'x-ms-permissions': 'REDACTED'
#     'Date': 'Fri, 19 May 2023 18:19:35 GMT'
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %% [markdown]
# ## 4.) Ingest the Canvas Module Test Data
#
# Directory: ```stage1/Transactional/canvas -> stage2/Ingested/canvas```
#
# This step ingests the Canvas module test data from stage1 to stage2/Ingested.
#
# The code blocks in this step ingest the data using the ```oea.ingest()``` function as normal.
#
# **To-Do's:**
#  - Check if Canvas test data accurately reflects actual (production) Canvas data.

# %%
# 3) The next step is to ingest the batch data into stage2
# Note that when you run this the first time, you'll see an info message like "Number of new inbound rows processed: 2".
# If you run this a second time, the number of inbound rows processed will be 0 because the ingestion uses spark structured streaming to keep track of what data has already been processed.
oea.ingest(f'canvas/v2.0/accounts', 'id')
#oea.ingest(f'canvas/v2.0/assignments', 'id')
#oea.ingest(f'canvas/v2.0/assignment_submissions', 'anonymous_id')
#oea.ingest(f'canvas/v2.0/assignment_submission_summary', 'assignment_id')
oea.ingest(f'canvas/v2.0/courses', 'id')
oea.ingest(f'canvas/v2.0/course_sections', 'id')
oea.ingest(f'canvas/v2.0/enrollments', 'id')
oea.ingest(f'canvas/v2.0/enrollment_terms', 'id')
oea.ingest(f'canvas/v2.0/roles', 'id')
oea.ingest(f'canvas/v2.0/users', 'id')
# Out:
# StatementMeta(spark3p3sm, 2, 54, Finished, Available)
# 2023-05-19 18:20:06,650 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/accounts, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/accounts/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:20:07,777 - py4j.java_gateway - INFO - Callback Server Starting
# 2023-05-19 18:20:07,778 - py4j.java_gateway - INFO - Socket listening on ('127.0.0.1', 36129)
# 2023-05-19 18:20:09,449 - py4j.java_gateway - INFO - Callback Connection ready to receive messages
# 2023-05-19 18:20:09,455 - py4j.java_gateway - INFO - Received command c on object id p0
# 2023-05-19 18:20:26,033 - OEA - INFO - Number of new inbound rows processed: 180
# 2023-05-19 18:20:34,965 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/courses, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/courses/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:20:37,305 - py4j.java_gateway - INFO - Received command c on object id p1
# 2023-05-19 18:20:42,502 - OEA - INFO - Number of new inbound rows processed: 87
# 2023-05-19 18:20:44,075 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/course_sections, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/course_sections/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:20:46,103 - py4j.java_gateway - INFO - Received command c on object id p2
# 2023-05-19 18:20:52,681 - OEA - INFO - Number of new inbound rows processed: 87
# 2023-05-19 18:20:54,352 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/enrollments, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/enrollments/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:20:56,220 - py4j.java_gateway - INFO - Received command c on object id p3
# 2023-05-19 18:21:02,515 - OEA - INFO - Number of new inbound rows processed: 3687
# 2023-05-19 18:21:04,172 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/enrollment_terms, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/enrollment_terms/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:21:05,939 - py4j.java_gateway - INFO - Received command c on object id p4
# 2023-05-19 18:21:09,888 - OEA - INFO - Number of new inbound rows processed: 2
# 2023-05-19 18:21:11,746 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/roles, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/roles/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:21:13,580 - py4j.java_gateway - INFO - Received command c on object id p5
# 2023-05-19 18:21:16,963 - OEA - INFO - Number of new inbound rows processed: 2
# 2023-05-19 18:21:19,055 - OEA - INFO - Ingesting from: stage1/Transactional/canvas/v2.0/users, batch type of: snapshot, source data format of: csv
# source_path is: abfss://oea@stoeacisd3v08oct.dfs.core.windows.net/dev/stage1/Transactional/canvas/v2.0/users/snapshot_batch_data/rundate=2023-05-19 18-19-17
# 2023-05-19 18:21:20,789 - py4j.java_gateway - INFO - Received command c on object id p6
# 2023-05-19 18:21:25,356 - OEA - INFO - Number of new inbound rows processed: 640
# 640

# %%
# 3.5) Now you can run queries against the auto-generated "lake database" with the ingested Canvas data.
df = spark.sql("select * from ldb_dev_s2i_canvas_v2p0.course_sections")
display(df.limit(10))
# Out:
# StatementMeta(spark3p3sm, 2, 55, Finished, Available)
# SynapseWidget(Synapse.DataFrame, bedf0aa4-03fe-435e-928c-62bb77593d01)

# %% [markdown]
# ## 5.) Refine the Canvas Module Test Data
#
# Directory: ```stage2/Ingested/canvas -> stage2/Refined/canvas```
#
# This step then refines the Canvas test data from stage2/Ingested to stage2/Refined, using the metadata.csv. This step is responsible for pseudonymization, which preserves sensitive student information by either hashing or masking the sensitive columns.
#
# Tables are separated into either ```stage2/Refined/canvas/v2.0/general``` or ```stage2/Refined/canvas/v2.0/sensitive```, depending on whether each table is pseudonymized or has a sensitive column-hashing/masking mapping, respectively.

# %%
def refine_canvas(entity_path, metadata=None, primary_key='id'):
    source_path = f'stage2/Ingested/{entity_path}'
    primary_key = oea.fix_column_name(primary_key) # fix the column name, in case it has a space in it or some other invalid character
    path_dict = oea.parse_path(source_path)
    sink_general_path = path_dict['entity_parent_path'].replace('Ingested', 'Refined') + '/general/' + path_dict['entity']
    sink_sensitive_path = path_dict['entity_parent_path'].replace('Ingested', 'Refined') + '/sensitive/' + path_dict['entity'] + '_lookup'
    if not metadata:
        all_metadata = oea.get_metadata_from_path(path_dict['entity_parent_path'])
        metadata = all_metadata[path_dict['entity']]

    df_changes = oea.get_latest_changes(source_path, sink_general_path)
    spark_schema = oea.to_spark_schema(metadata)
    df_changes = oea.modify_schema(df_changes, spark_schema)        

    if df_changes.count() > 0:
        df_pseudo, df_lookup = oea.pseudonymize(df_changes, metadata)
        oea.upsert(df_pseudo, sink_general_path, primary_key) # todo: remove this assumption that the primary key will always be hashed during pseduonymization
        oea.upsert(df_lookup, sink_sensitive_path, primary_key)    
        oea.add_to_lake_db(sink_general_path)
        oea.add_to_lake_db(sink_sensitive_path)
        logger.info(f'Processed {df_changes.count()} updated rows from {source_path} into stage2/Refined')
    else:
        logger.info(f'No updated rows in {source_path} to process.')
    return df_changes.count()
# Out:
# StatementMeta(spark3p3sm, 2, 56, Finished, Available)

# %%
# 4) this step refines the data through the use of metadata (this is where the pseudonymization of the data occurs).
def refine_canvas_dataset(tables_source):
    items = oea.get_folders(tables_source)
    for item in items: 
        table_path = tables_source +'/'+ item
        if item == 'metadata.csv':
            logger.info('ignore metadata processing, since this is not a table to be ingested')
        else:
            try:
                if item == 'accounts':
                    refine_canvas('canvas/v2.0/accounts', metadata[item], 'id_pseudonym')
                elif item == 'users':
                    refine_canvas('canvas/v2.0/users', metadata[item], 'id_pseudonym')
                else:
                    refine_canvas('canvas/v2.0/' + item, metadata[item], 'id')
            except AnalysisException as e:
                # This means the table may have not been properly refined due to errors with the primary key not aligning with columns expected in the lookup table.
                pass
            
            logger.info('Refined table: ' + item + ' from: ' + table_path)
    logger.info('Finished refining Canvas tables')
# Out:
# StatementMeta(spark3p3sm, 2, 57, Finished, Available)

# %%
metadata = oea.get_metadata_from_url('https://raw.githubusercontent.com/cstohlmann/oea-canvas-module/main/test_data/metadata.csv')
refine_canvas_dataset('stage2/Ingested/canvas/v2.0')
# Out:
# StatementMeta(spark3p3sm, 2, 58, Finished, Available)
# 2023-05-19 18:26:47,288 - OEA - INFO - Processed 180 updated rows from stage2/Ingested/canvas/v2.0/accounts into stage2/Refined
# 2023-05-19 18:26:47,591 - OEA - INFO - Refined table: accounts from: stage2/Ingested/canvas/v2.0/accounts
# 2023-05-19 18:26:51,525 - OEA - INFO - Refined table: course_sections from: stage2/Ingested/canvas/v2.0/course_sections
# 2023-05-19 18:26:55,337 - OEA - INFO - Refined table: courses from: stage2/Ingested/canvas/v2.0/courses
# 2023-05-19 18:26:58,905 - OEA - INFO - Refined table: enrollment_terms from: stage2/Ingested/canvas/v2.0/enrollment_terms
# 2023-05-19 18:27:02,996 - OEA - INFO - Refined table: enrollments from: stage2/Ingested/canvas/v2.0/enrollments
# 2023-05-19 18:27:06,611 - OEA - INFO - Refined table: roles from: stage2/Ingested/canvas/v2.0/roles
# 2023-05-19 18:27:17,008 - OEA - INFO - Processed 640 updated rows from stage2/Ingested/canvas/v2.0/users into stage2/Refined
# 2023-05-19 18:27:17,239 - OEA - INFO - Refined table: users from: stage2/Ingested/canvas/v2.0/users
# 2023-05-19 18:27:17,239 - OEA - INFO - Finished refining Canvas tables

# %% [markdown]
# ## 6.) Demonstrate Lake Database Queries/Final Remarks

# %%
# non-hashed primary keys are not automatically added to the lake db - add these tables
oea.add_to_lake_db('stage2/Refined/canvas/v2.0/general/courses')
oea.add_to_lake_db('stage2/Refined/canvas/v2.0/general/course_sections')
oea.add_to_lake_db('stage2/Refined/canvas/v2.0/general/enrollments')
oea.add_to_lake_db('stage2/Refined/canvas/v2.0/general/enrollment_terms')
oea.add_to_lake_db('stage2/Refined/canvas/v2.0/general/roles')
# Out:
# StatementMeta(spark3p3sm, 2, 61, Finished, Available)

# %%
# 5) Now you can query the refined data tables in the lake db
df = spark.sql("select * from ldb_dev_s2r_canvas_v2p0.enrollments")
display(df)
df.printSchema()
df = spark.sql("select * from ldb_dev_s2r_canvas_v2p0.users")
display(df)
df.printSchema()
# You can use the "lookup" table for joins (people with restricted access won't be able to perform this query because they won't have access to data in the "sensitive" folder in the data lake)
df = spark.sql("select e.course_section_id, e.type, e.workflow_state, u.id_pseudonym, u.name \
                from ldb_dev_s2r_canvas_v2p0.enrollments e, ldb_dev_s2r_canvas_v2p0.users u where e.user_id_pseudonym = u.id_pseudonym")
display(df.limit(10))
# Out:
# StatementMeta(spark3p3sm, 2, 62, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 8b291fdd-def3-4ce1-9e1f-8c6657b118fe)
# root
#  |-- id: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- workflow_state: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- start_at: timestamp (nullable = true)
#  |-- end_at: timestamp (nullable = true)
#  |-- completed_at: timestamp (nullable = true)
#  |-- self_enrolled: boolean (nullable = true)
#  |-- last_activity_at: timestamp (nullable = true)
#  |-- course_section_id: integer (nullable = true)
#  |-- user_id_pseudonym: string (nullable = true)
# SynapseWidget(Synapse.DataFrame, e05f7a30-f648-4fbf-9439-ba6197897f4c)
# root
#  |-- id_pseudonym: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- time_zone: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- locale: string (nullable = true)
#  |-- workflow_state: string (nullable = true)
#  |-- sortable_name: string (nullable = true)
#  |-- school_name: string (nullable = true)
#  |-- school_position: string (nullable = true)
#  |-- public: boolean (nullable = true)
#  |-- global_canvas_id_pseudonym: string (nullable = true)
# SynapseWidget(Synapse.DataFrame, 57a439f4-b56d-4d83-9aae-c51b406b5aa0)

# %%
# Run this cell to reset this example (deleting all the example Canvas data in your workspace)
oea.rm_if_exists('stage1/Transactional/canvas')
oea.rm_if_exists('stage2/Ingested/canvas')
oea.rm_if_exists('stage2/Refined/canvas')
oea.drop_lake_db('ldb_dev_s2i_canvas_v2p0')
oea.drop_lake_db('ldb_dev_s2r_canvas_v2p0')

# %% [markdown]
# ## Appendix

# %%
# generate an initial metadata file for manual modification
metadata = oea.create_metadata_from_lake_db('ldb_dev_s2i_canvas_v2p0')
dlw = DataLakeWriter(oea.to_url('stage1/Transactional/canvas'))
dlw.write('metadata.csv', metadata)

# %%
# Create a sql db for the ingested Canvas data
oea.create_sql_db('stage2/Ingested/canvas')

# %%
oea.create_sql_db('stage2/Refined/canvas')
# Out:
# StatementMeta(spark3p2sm, 20, 14, Finished, Available)
# -- Create a new sql script then execute the following in it:
# IF NOT EXISTS (SELECT * FROM sys.databases WHERE name = 'sdb_dev_s2r_moodle')
# BEGIN
#   CREATE DATABASE sdb_dev_s2r_moodle;
# END;
# GO
# USE sdb_dev_s2r_moodle;
# GO
#
# CREATE OR ALTER VIEW v4.1 AS
#   SELECT * FROM OPENROWSET(BULK 'abfss://oea@stoeacisd3v08kw1.dfs.core.windows.net/dev/stage2/Refined/moodle/v4.1', FORMAT='delta') AS [r];
# GO
